# %% [markdown]
# # Intelligent Distribution System for Target Corporation

# %% [markdown]
# ### Note:
#
# 1. This is a group-based project, you are only allowed to discuss with your team members.
#
# 2. You are not allowed to use any packages to read or write csv files.

# %% [markdown]
# ## Problem1: Optimal Value Estimation for Distribution Centers

# %% [markdown]
# In this problem 1, you need to calculate the estimated total value and accumulated weight of each of 300 distribution centers.

# %% [markdown]
# ### Step 1: Estimate the Maximized Total Value and Accumulated Weight of One Distribution Center

# %% [markdown]
# ## 📖 What are we trying to do in Problem 1?
#
# **Think of it like this**: Imagine you're the manager of Target's toy warehouse! 🧸
#
# You have a **big CSV file** full of toys (products), and each toy has:
# - A **unique ID number** (like a barcode)
# - A **value** (how much it's worth in dollars 💰)
# - A **weight** (how heavy it is in pounds ⚖️)
#
# Your job is to fill up **300 different trucks** (distribution centers), but each truck can only carry a certain amount of weight. You want to make each truck as **valuable** as possible by choosing the **best toys** to put in it!
#
# The trick? **Choose toys that give you the most "bang for your buck"** - toys that are very valuable but don't weigh too much!
#
# ### Step 1: Read the dataset from "Products.csv" first.
#
# First, we need to **read our toy catalog** (the CSV file) without using any special libraries - we have to do it the "old-fashioned way" by opening the file and reading it line by line, just like reading a book! 📚

# %%
# 📚 HOW TO READ THE CSV FILE (Your First Challenge!)

"""
💡 WHAT YOU NEED TO UNDERSTAND:

The CSV file is structured in a special way:
- Line 1: Lists all the product IDs (like: 1, 2, 3, 4, 5...)
- Line 2: Lists all the product values (like: 100.5, 250.0, 75.25...)
- Line 3: Just separator marks (commas and dashes - you can ignore this)
- Then it repeats this pattern!

Your job: Match up each ID with its value, and calculate a reasonable weight.
"""

# 🎯 STEP-BY-STEP CODING GUIDE:

# Step 1: Create a function called read_csv(filename)
def read_csv(filename):
    """
    This function should:
    1. Open the CSV file and read all lines
    2. Process lines in groups of 3 (ID line, Value line, Separator line)
    3. Match IDs with their values
    4. Calculate weights for each product
    5. Return a list of [ID, Value, Weight] for each product
    """
    
    # TODO: Create an empty list to store your products
    products = []
    
    # TODO: Open the file and read all lines into a list
    # HINT: Use with open(filename, 'r') as file: lines = file.readlines()
    
    # TODO: Process lines in groups of 3
    # HINT: Use a while loop with i starting at 0, incrementing by 3 each time
    
    # TODO: For each group, split the ID line and value line by commas
    # HINT: Use .split(',') and .strip() to clean up the data
    
    # TODO: Match each ID with its corresponding value
    # HINT: Use min(len(id_list), len(value_list)) to avoid index errors
    
    # TODO: Calculate a reasonable weight for each product
    # HINT: You can use something like: weight = max(1, value * 0.6 + (product_id % 20) + 5)
    
    # TODO: Add [product_id, value, weight] to your products list
    
    # TODO: Return the products list
    
    pass  # Remove this line when you add your code

# 🧪 TESTING YOUR FUNCTION:
# After you write your function, uncomment these lines to test it:

# products_data = read_csv('Products.csv')
# print(f"Found {len(products_data)} products")
# print("First 3 products:", products_data[:3])

# %% [markdown]
# ## 🎯 The Big Challenge: The "get_max_value" Function
#
# Now comes the **most important part** of Problem 1! We need to write a special function called "get_max_value" that acts like a **super-smart shopping assistant**! 🛒
#
# ### 🤔 What does this function need to do?
#
# Imagine you're at a candy store with your allowance money, but you can only carry 15 pounds of candy in your backpack. You want to get the **most value for your money** while staying under the weight limit!
#
# **The get_max_value function is like having a genius friend who can:**
# 1. 🧮 **Calculate a "bang-for-your-buck" score** for every single piece of candy (Value ÷ Weight)
# 2. 📊 **Sort all the candy** from best score to worst score
# 3. 🎯 **Pick the best candies** one by one, making sure your backpack doesn't get too heavy
# 4. 💰 **Tell you the total value** of all the candy you picked and how much it all weighs
#
# ### 📝 The 4 Things Our Function Must Do:

# %% [markdown]
# 1. Calculate the Value Weight Ratio for each product.
# 2. Sort the calculated Value Weight Ratios in descending order.
# 3. Select the products from the top of the descending order while monitoring the accumulated weight of products to ensure it does not exceed the distribution center's weight capacity.
# 4. Calculate the corresponding estimated value for this distribution center after completing product selection.

# %% [markdown]
# Remember, consider every product carefully; otherwise, you may risk missing valuable items. You want to select as many products with the highest Value Weight Ratio as possible before reaching the weight capacity for this distribution center.

# %%
# 🧠 HOW TO WRITE THE get_max_value FUNCTION (The Super-Smart Shopping Assistant!)

"""
🍭 THINK OF IT LIKE THIS:

You're at a candy store with a 15-pound backpack. Each candy has:
- A price (value)  
- A weight
- A "value-per-pound" score (price ÷ weight)

Your strategy: Always pick the candy with the highest value-per-pound first!
Keep picking until your backpack is full.
"""

# 🎯 STEP-BY-STEP CODING GUIDE:

def get_max_value(products, weight_capacity):
    """
    This is your SUPER-SMART function! It should:
    
    Parameters:
        products: List of [product_id, value, weight] 
        weight_capacity: Maximum weight your "truck" can carry
    
    Returns:
        total_value: Total value of selected products
        total_weight: Total weight of selected products
    """
    
    # STEP 1: Calculate value-to-weight ratio for each product
    # TODO: Create a new list to store [product_id, value, weight, ratio]
    # HINT: For each product, calculate ratio = value / weight
    # HINT: Make sure weight > 0 to avoid division by zero!
    
    # STEP 2: Sort products by ratio in DESCENDING order (best first)
    # TODO: Sort your list by the ratio (4th element), highest first
    # HINT: Use .sort(key=lambda x: x[3], reverse=True)
    
    # STEP 3: Greedy selection (pick the best products that fit)
    # TODO: Create variables for total_value = 0, total_weight = 0
    # TODO: Loop through your sorted products
    # TODO: For each product, check: if (total_weight + product_weight <= weight_capacity)
    # TODO: If it fits, add it to your totals!
    
    # STEP 4: Return the results
    # TODO: Return total_value, total_weight
    
    pass  # Remove this line when you add your code

# 🧪 TESTING YOUR FUNCTION:
# After you write your function, test it with this small example:

# Test data: [ID, Value, Weight]
test_products = [
    [1, 100, 10],  # Ratio = 10.0
    [2, 60, 20],   # Ratio = 3.0  
    [3, 80, 5],    # Ratio = 16.0 (BEST!)
    [4, 40, 30],   # Ratio = 1.33
]

# Expected result: Should pick products 3, 1 (total value=180, weight=15)
# Uncomment to test:
# value, weight = get_max_value(test_products, 35)
# print(f"Total value: {value}, Total weight: {weight}")

# %% [markdown]
# ### Step 2: Scale Up - Do This for 300 Distribution Centers!
#
# ## 🚛 The Big Picture: 300 Trucks Need Loading!
#
# Now that we have our **super-smart function**, we need to use it **300 times** - once for each of Target's distribution centers (trucks)!
#
# **Think of it like this:**
# - Target has 300 warehouses across the country 🗺️
# - Each warehouse has trucks that can carry different amounts of weight
# - We need to load EACH truck with the most valuable products possible
# - Then add up ALL the values to see how much money Target can make!
#
# **It's like being the manager of 300 candy stores, and calculating the total profit from all stores combined!** 💰

# %%
# 🏭 HOW TO MANAGE 300 DISTRIBUTION CENTERS

"""
🎮 THINK OF IT LIKE A VIDEO GAME:

You're managing 300 different cities in a strategy game.
Each city has:
- A different truck size (random capacity between 800-1500 lbs)
- The same products available
- Goal: Maximize TOTAL value across ALL cities!
"""

# 🎯 STEP-BY-STEP CODING GUIDE:

import random  # We'll need this for random truck capacities

def calculate_total_for_300_centers(products):
    """
    This function manages all 300 distribution centers!
    
    It should:
    1. Create 300 centers with random capacities (800-1500 lbs each)
    2. Use your get_max_value function for each center
    3. Add up all the results
    4. Return the grand total
    """
    
    # TODO: Set random seed for consistent results
    # HINT: random.seed(42)
    
    # TODO: Create variables for total_system_value = 0, total_system_weight = 0
    
    # TODO: Loop 300 times (for center_id in range(300))
    # TODO: For each center, generate random capacity between 800-1500
    # HINT: capacity = random.randint(800, 1500)
    
    # TODO: Call your get_max_value function for this center
    # HINT: center_value, center_weight = get_max_value(products, capacity)
    
    # TODO: Add this center's results to your totals
    # HINT: total_system_value += center_value
    
    # TODO: Return total_system_value, total_system_weight
    
    pass  # Remove this line when you add your code

# 🧪 TESTING YOUR FUNCTION:
# After you write both functions, test the whole system:

# Step 1: Read the products (uncomment when ready)
# products_data = read_csv('Products.csv')

# Step 2: Calculate for 300 centers (uncomment when ready) 
# system_value, system_weight = calculate_total_for_300_centers(products_data)

# Step 3: Display results (uncomment when ready)
# print(f"Total system value: ${system_value:,.2f}")
# print(f"That's ${system_value/1000000:.1f} million dollars!")
# print(f"Average per center: ${system_value/300:,.2f}")

# %% [markdown]
# ## Problem 2: Optimal Supply Chain Partner Selection
#
# # 🌍 Welcome to Problem 2: The Supplier Olympics!
#
# ## 🤔 What's This All About?
#
# **Problem 1 was about loading trucks.** Now **Problem 2 is about finding the BEST suppliers!** 🏭
#
# **Think of it like this:** Target needs to buy 3 types of products (X, Y, and Z) from suppliers around the country. But there's a catch:
#
# 1. **There are 150 different suppliers** to choose from! 🏭🏭🏭...
# 2. **Each supplier offers different deals** (prices and quantities)
# 3. **It costs money to transport products** from each supplier to Target! 🚛💰
# 4. **One random supplier is closed** (unavailable) 🚫
# 5. **We need to find the TOP 3 best suppliers** for each product type 🥇🥈🥉
#
# **It's like planning the world's most complicated shopping trip, where shipping costs matter a LOT!**

# %% [markdown]
# ### Step 1: Generate a Transportation Cost Matrix
#
# ## 🗺️ Step 1: Create Our "Distance Map"
#
# **What we're doing:** Creating a **150×150 table** that tells us how much it costs to ship products between any two locations.
#
# **Think of it like this:**
# - Imagine you have 150 cities on a map 🏙️
# - You need to know the **shipping cost** from **any city** to **any other city**
# - Some routes are cheap (nearby cities), some are expensive (far cities)
# - It should cost $0 to ship from a city to itself (no shipping needed!)
#
# **The Magic Formula:** We use something called "normal distribution" to create realistic shipping costs. It's like rolling a special dice that usually gives numbers around 750, but sometimes gives higher or lower numbers!
#
# **Requirements:**
# - Generate a transportation cost matrix of size **150x150**.
# - Each cost should be generated using a normal distribution with a mean of **750** and a standard deviation of **200**.
# - Ensure all costs are positive, and round them to the nearest integer.
# - Save the transportation cost matrix to a file named `Transportation_Costs.csv`.

# %%
# 🎲 HOW TO CREATE THE TRANSPORTATION COST MATRIX

"""
🎯 THINK OF IT LIKE THIS:

You're creating a giant board game with 150 cities.
Each cell (i,j) shows: "How much to ship from city i to city j?"
- Diagonal cities (i,i) cost $0 (no shipping to yourself!)
- Other cities cost random amounts around $750

We use "Box-Muller transform" - a math trick to create realistic random numbers!
"""

import random
import math

# 🎯 STEP-BY-STEP CODING GUIDE:

def generate_normal_random(mean, std_dev):
    """
    This creates random numbers that follow a "bell curve" pattern.
    Most numbers will be close to 750, some higher, some lower.
    
    TODO: Implement the Box-Muller transform:
    1. Get two random numbers between 0 and 1
    2. Apply this formula: z = sqrt(-2 * log(u1)) * cos(2 * pi * u2)  
    3. Return: mean + z * std_dev
    """
    
    # TODO: u1 = random.random()
    # TODO: u2 = random.random()
    # TODO: z = math.sqrt(-2 * math.log(u1)) * math.cos(2 * math.pi * u2)
    # TODO: return mean + z * std_dev
    
    pass  # Remove this line when you add your code

def create_transportation_matrix():
    """
    Creates a 150×150 matrix of shipping costs.
    
    TODO: This function should:
    1. Set random seed to 123 for consistent results
    2. Create a 150×150 matrix (list of lists)
    3. Fill diagonal with 0s (same city = no cost)  
    4. Fill other cells with normal random numbers (mean=750, std=200)
    5. Make sure all costs are positive integers
    6. Return the matrix
    """
    
    # TODO: random.seed(123)
    # TODO: matrix = []
    # TODO: for i in range(150):
    # TODO:     row = []
    # TODO:     for j in range(150):
    # TODO:         if i == j:
    # TODO:             cost = 0  # Same city
    # TODO:         else:
    # TODO:             cost = generate_normal_random(750, 200)
    # TODO:             cost = max(1, round(cost))  # Positive integer
    # TODO:         row.append(cost)
    # TODO:     matrix.append(row)
    # TODO: return matrix
    
    pass  # Remove this line when you add your code

def save_matrix_to_csv(matrix, filename):
    """
    Saves the matrix to a CSV file.
    
    TODO: This function should:
    1. Open the file for writing
    2. For each row, join numbers with commas
    3. Write each row as a line in the file
    """
    
    # TODO: with open(filename, 'w') as file:
    # TODO:     for row in matrix:
    # TODO:         row_text = ','.join(map(str, row))
    # TODO:         file.write(row_text + '\n')
    
    pass  # Remove this line when you add your code

# 🧪 TESTING YOUR FUNCTIONS:
# After you write your functions, uncomment these lines:

# transportation_matrix = create_transportation_matrix()
# save_matrix_to_csv(transportation_matrix, 'Transportation_Costs.csv')
# print("Matrix created and saved!")
# print(f"Matrix size: {len(transportation_matrix)} x {len(transportation_matrix[0])}")
# print(f"Sample costs: {transportation_matrix[0][:5]}")

# %% [markdown]
# ### Step 2: Generate Supplier Data
#
# ## 🏭 Step 2: Create Our Supplier Database
#
# **What we're doing:** Creating 150 different suppliers, each offering 3 types of products (X, Y, and Z), but with one supplier randomly unavailable!
#
# **Think of it like this:**
# - Imagine 150 different toy factories around the country 🏭
# - Each factory makes 3 types of toys: **Toy X** (like action figures), **Toy Y** (like dolls), **Toy Z** (like puzzles)
# - Each factory offers different **prices** and **quantities** for each toy type
# - **One factory is randomly closed for repairs** (unavailable) 🚫
# - We need to create a catalog of what each factory offers!
#
# **The Challenge:** Each product type has different price and weight ranges (because some toys are naturally more expensive or heavier than others).
#
# **Requirements:**
# - Randomly select one supplier (from 0 to 149) as the **unavailable supplier**.
# - For each supplier (including the unavailable supplier), generate random values for the following attributes for **three product categories (X, Y, and Z)**:
#   - `Total_Value`: Random integer between 2500 and 12000 for Product X, 3500 to 18000 for Product Y, and 1800 to 10000 for Product Z.
#   - `Total_Weight`: Random integer between 400 and 2500 for Product X, 800 to 4500 for Product Y, and 600 to 3000 for Product Z.
# - You will use these values in the next step to calculate the Value_per_Weight for each Available supplier.

# %%
# 🏭 HOW TO CREATE THE SUPPLIER DATABASE

"""
🎨 THINK OF IT LIKE THIS:

You're creating a catalog of 150 art supply stores.
Each store sells 3 types of supplies:
- Product X: Paintbrushes (medium price range, lighter weight)
- Product Y: Canvas sets (higher price range, heavier weight)  
- Product Z: Colored pencils (lower price range, medium weight)

One random store is closed for renovations!
"""

def create_supplier_database():
    """
    Creates data for 150 suppliers, each offering products X, Y, and Z.
    One random supplier will be unavailable.
    
    TODO: This function should:
    1. Set random seed to 456 for consistent results  
    2. Randomly pick one supplier (0-149) to be unavailable
    3. For each supplier, generate data for products X, Y, Z
    4. Return suppliers dictionary and unavailable supplier ID
    """
    
    # TODO: random.seed(456)
    # TODO: unavailable_supplier = random.randint(0, 149)
    
    # TODO: Define product specifications:
    # Product X: value 2500-12000, weight 400-2500
    # Product Y: value 3500-18000, weight 800-4500  
    # Product Z: value 1800-10000, weight 600-3000
    
    # TODO: suppliers_data = {}
    
    # TODO: for supplier_id in range(150):
    # TODO:     supplier_products = {}
    # TODO:     for each product type ['X', 'Y', 'Z']:
    # TODO:         Generate random total_value within range
    # TODO:         Generate random total_weight within range
    # TODO:         Store in supplier_products[product_type]
    # TODO:     Store supplier info with 'available' status
    
    # TODO: return suppliers_data, unavailable_supplier
    
    pass  # Remove this line when you add your code

# 🧪 TESTING YOUR FUNCTION:
# After you write your function, uncomment these lines:

# suppliers, unavailable_supplier_id = create_supplier_database()
# print(f"Created database for 150 suppliers")
# print(f"Unavailable supplier: {unavailable_supplier_id}")
# print(f"Sample supplier 0 data: {suppliers[0]}")

# %% [markdown]
# ### Step 3: Calculate Value_per_Weight
#
# ## 🧮 Step 3: The Big Calculation - Who Gives the Best Deal?
#
# **What we're doing:** For each product type (X, Y, Z), we need to figure out which suppliers give us the **best value for our money** when we include shipping costs!
#
# **Think of it like online shopping:** 🛒
# - You find a great deal on a product, but then you see the **shipping cost**! 📦💸
# - Sometimes a slightly more expensive product with **free shipping** is actually the better deal
# - We need to calculate the **true value** after accounting for transportation costs
# - Then find the **TOP 3 best deals** for each product type
#
# **The Magic Formula:**
#
# ![Value_per_Weight Formula](attachment:da6677b8-89a6-4dbc-82ac-6e8b05397735.png)
#
# **In simple terms:**
# - **Transportation_Cost** = distance_units × 0.018 (like a shipping rate of $0.018 per mile)
# - **Value_per_Weight** = (Product_Value - Shipping_Cost) ÷ Product_Weight
# - **Higher is better** - we want the most value per pound after paying for shipping!
#
# **Requirements:**
# - For each product (X, Y, and Z), calculate the Value_per_Weight for all Available suppliers (excluding the unavailable supplier).
# - Transportation_Cost: The transportation cost is 0.018 per cost unit.
# - For each product, sort the Available suppliers by the Value_per_Weight in descending order.
# - Select the top 3 Available suppliers with the highest Value_per_Weight for each product.

# %%
# 🏆 HOW TO FIND THE BEST SUPPLIERS (The Ultimate Deal Finder!)

"""
🛒 THINK OF IT LIKE ONLINE SHOPPING:

You're comparing deals for phones, laptops, and tablets from 149 stores.
For each store, you calculate:
1. The product value (how good the deal is)
2. The shipping cost (varies by distance)  
3. The "value per pound" after paying shipping
4. Pick the TOP 3 stores for each product type!
"""

def find_best_suppliers(suppliers_data, transportation_matrix, unavailable_supplier_id):
    """
    Finds the top 3 suppliers for each product type based on value-per-weight
    after accounting for transportation costs.
    
    TODO: This function should:
    1. For each product type (X, Y, Z):
       - Evaluate all available suppliers (skip unavailable one)
       - Calculate transportation cost using matrix
       - Calculate value_per_weight = (value - transport_cost) / weight  
       - Sort suppliers by value_per_weight (highest first)
       - Select top 3 suppliers
    2. Return dictionary with top 3 suppliers for each product
    """
    
    # TODO: transportation_cost_rate = 0.018
    # TODO: results = {}
    # TODO: target_location = 0  # We're shipping to location 0
    
    # TODO: for product_type in ['X', 'Y', 'Z']:
    # TODO:     supplier_evaluations = []
    # TODO:     
    # TODO:     for supplier_id in range(150):
    # TODO:         if supplier_id == unavailable_supplier_id:
    # TODO:             continue  # Skip unavailable supplier
    # TODO:         
    # TODO:         Get supplier data for this product type
    # TODO:         total_value = supplier['products'][product_type]['total_value']
    # TODO:         total_weight = supplier['products'][product_type]['total_weight']
    # TODO:         
    # TODO:         Get transportation cost from matrix
    # TODO:         transport_cost_units = transportation_matrix[target_location][supplier_id]  
    # TODO:         transportation_cost = transport_cost_units * transportation_cost_rate
    # TODO:         
    # TODO:         Calculate value_per_weight
    # TODO:         if total_weight > 0:
    # TODO:             value_per_weight = (total_value - transportation_cost) / total_weight
    # TODO:             
    # TODO:         Store evaluation data
    # TODO:         supplier_evaluations.append({...})
    # TODO:     
    # TODO:     Sort by value_per_weight (highest first)
    # TODO:     supplier_evaluations.sort(key=lambda x: x['value_per_weight'], reverse=True)
    # TODO:     
    # TODO:     Select top 3
    # TODO:     results[product_type] = supplier_evaluations[:3]
    # TODO: 
    # TODO: return results
    
    pass  # Remove this line when you add your code

# 🧪 TESTING YOUR FUNCTION:
# After you write your function, uncomment these lines:

# top_suppliers = find_best_suppliers(suppliers, transportation_matrix, unavailable_supplier_id)
# print("Top 3 suppliers found for each product!")
# for product in ['X', 'Y', 'Z']:
#     best = top_suppliers[product][0]
#     print(f"Product {product}: Best supplier is #{best['supplier_id']} with score {best['value_per_weight']:.4f}")

# %% [markdown]
# ### Step 4: Output the Results
#
# ## 🏆 Step 4: The Grand Reveal - Our Championship Results!
#
# **What we're doing:** Presenting our findings in a clear, organized way that shows exactly which suppliers Target should choose for each product type!
#
# **Think of it like announcing the winners of a cooking competition:** 👨‍🍳
# - We have 3 categories: **Product X**, **Product Y**, and **Product Z**
# - For each category, we announce the **1st, 2nd, and 3rd place winners** 🥇🥈🥉
# - We show exactly **why** each winner is great (their value-per-weight score)
# - We include all the **important details** (original value, shipping cost, final score)
#
# **Requirements:**
# - Output the top 3 Available suppliers for each product, along with their calculated **Value_per_Weight**.
# - Ensure the results for Product X, Y, and Z are displayed separately.

# %%
# 🎉 HOW TO PRESENT YOUR CHAMPIONSHIP RESULTS!

"""
🏆 THINK OF IT LIKE AN AWARDS SHOW:

You're hosting "The Best Supplier Awards"!
For each product category (X, Y, Z), you announce:

🥇 GOLD MEDAL: Best value-per-weight  
🥈 SILVER MEDAL: Second best value-per-weight
🥉 BRONZE MEDAL: Third best value-per-weight

For each winner, show their details!
"""

def display_championship_results(top_suppliers_results, unavailable_supplier_id):
    """
    Creates a beautiful presentation of your supplier selection results.
    
    TODO: This function should:
    1. Print a nice header with summary info
    2. For each product type (X, Y, Z):
       - Show the top 3 suppliers 
       - Display their key statistics
       - Show why each one is good
    3. Create a summary table at the end
    """
    
    # TODO: Print header and summary
    # TODO: print("="*80)
    # TODO: print("🏆 TARGET'S OPTIMAL SUPPLY CHAIN PARTNERS 🏆")
    # TODO: print(f"Unavailable supplier: {unavailable_supplier_id}")
    
    # TODO: For each product type:
    # TODO: for product_type in ['X', 'Y', 'Z']:
    # TODO:     print(f"\n🏆 PRODUCT {product_type} WINNERS 🏆")
    # TODO:     suppliers_list = top_suppliers_results[product_type]
    # TODO:     
    # TODO:     For each of the top 3 suppliers:
    # TODO:     medals = ["🥇 GOLD", "🥈 SILVER", "🥉 BRONZE"]  
    # TODO:     for rank, supplier in enumerate(suppliers_list):
    # TODO:         medal = medals[rank]
    # TODO:         print(f"{medal} - Supplier #{supplier['supplier_id']}")
    # TODO:         print(f"  Value: ${supplier['total_value']:,}")
    # TODO:         print(f"  Weight: {supplier['total_weight']:,} lbs")
    # TODO:         print(f"  Shipping: ${supplier['transportation_cost']:.2f}")
    # TODO:         print(f"  SCORE: {supplier['value_per_weight']:.4f}")
    
    pass  # Remove this line when you add your code

# 🧪 PUTTING IT ALL TOGETHER:
# After you write all your functions, uncomment this section to run the complete analysis:

# print("🚀 RUNNING COMPLETE SUPPLIER ANALYSIS...")
# print("="*60)

# Step 1: Create transportation matrix
# transportation_matrix = create_transportation_matrix()
# save_matrix_to_csv(transportation_matrix, 'Transportation_Costs.csv')
# print("✅ Transportation matrix created and saved!")

# Step 2: Create supplier database  
# suppliers, unavailable_supplier_id = create_supplier_database()
# print("✅ Supplier database created!")

# Step 3: Find best suppliers
# top_suppliers = find_best_suppliers(suppliers, transportation_matrix, unavailable_supplier_id)
# print("✅ Best suppliers identified!")

# Step 4: Display results
# display_championship_results(top_suppliers, unavailable_supplier_id)
# print("✅ Analysis complete!")

print("🎯 Write your functions above, then uncomment the testing section to see results!")

# %% [markdown]
# #### Note: Due to random assignment of the unavailable supplier, it's expected that your recommended solution changes each time you re-run the code.

# %% [markdown]
# #### Submission Requirement: Please submit all files (Transportation_Costs.csv, and FL25_Midterm.ipynb files) as one zip file on Canvas. Please add IDs to the name of zip file. For example, 14325_34672_12345.zip.
